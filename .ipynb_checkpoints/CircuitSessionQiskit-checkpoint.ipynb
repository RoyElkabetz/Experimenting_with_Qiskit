# %% [markdown]
# # Qiskit Circuit Session with Kevin Krsulich on the usage of transpiler
# from [link](https://youtu.be/2T3163VjvWQ)

# %%
from qiskit import *
from qiskit.tools.visualization import plot_histogram
from qiskit.tools.monitor import job_monitor
# %matplotlib inline
IBMQ.load_account()
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %% [markdown]
# ### 3-qubit GHZ state
# $\vert \Psi\rangle = \frac{1}{\sqrt{2}}\left(\vert 0\rangle\vert 0\rangle\vert 0\rangle + \vert 1\rangle\vert 1\rangle\vert 1\rangle \right)$

# %%
qc_ghz = QuantumCircuit(3, 3)
qc_ghz.h(0)
qc_ghz.cx(0, 1)
qc_ghz.cx(0, 2)
qc_ghz.measure([0, 1, 2], [0, 1, 2])
qc_ghz.draw(output='mpl')

# %% [markdown]
# Simulating the GHZ state using a quantum simulator

# %%
qobj_ghz_simulator = compiler.assemble(qc_ghz)
aer_job_ghz = Aer.get_backend('qasm_simulator').run(qobj_ghz_simulator)

# %%
aer_job_ghz.status()
# Out:
# <JobStatus.DONE: 'job has successfully run'>

# %%
aer_job_ghz.result().get_counts()
# Out:
# {'111': 528, '000': 496}

# %% [markdown]
# Trying to run the curcuit on real quantum device (ibmq_vigo)

# %%
provider = IBMQ.get_provider('ibm-q')
ibmq_vigo = provider.get_backend('ibmq_vigo')

# %%
qobj_ghz_device = compiler.assemble(qc_ghz)
ghz_job = ibmq_vigo.run(qobj_ghz_device)

# %%
ghz_job.status()
# Out:
# <JobStatus.ERROR: 'job incurred error'>

# %%
ghz_job.error_message()
# Out:
# "The Qobj uses gates (['h']) that are not among the basis gates (['u1', 'u2', 'u3', 'cx', 'id']). Error code: 1106."

# %%
ibmq_vigo
# Out:
# <IBMQBackend('ibmq_vigo') from IBMQ(hub='ibm-q', group='open', project='main')>

# %% [markdown]
# #### Problem:
# We get an error because the ibmq_vigo device topology does not support a two qubit gate between qubits 0 and 1

# %% [markdown]
# #### Solution:
# Therefore, we use the "transpile" feature to transform and compile our GHZ circuit into an equivalent quantum circuit that is supported by the topology of the ibmq_vigo device.

# %%
tqc_ghz_vigo = transpile(qc_ghz, ibmq_vigo)
tqc_ghz_vigo.draw()
# Out:
#                                                ┌───┐ ░       ┌─┐
#       q_2 -> 0 ────────────────────────────────┤ X ├─░───────┤M├
#                            ┌───┐     ┌───┐     └─┬─┘ ░ ┌─┐   └╥┘
#       q_1 -> 1 ────────────┤ X ├──■──┤ X ├──■────■───░─┤M├────╫─
#                ┌──────────┐└─┬─┘┌─┴─┐└─┬─┘┌─┴─┐      ░ └╥┘┌─┐ ║
#       q_0 -> 2 ┤ U2(0,pi) ├──■──┤ X ├──■──┤ X ├──────░──╫─┤M├─╫─
#                └──────────┘     └───┘     └───┘      ░  ║ └╥┘ ║
# ancilla_0 -> 3 ──────────────────────────────────────░──╫──╫──╫─
#                                                      ░  ║  ║  ║
# ancilla_1 -> 4 ──────────────────────────────────────░──╫──╫──╫─
#                                                      ░  ║  ║  ║
#           c_0: ═════════════════════════════════════════╩══╬══╬═
#                                                            ║  ║
#           c_1: ════════════════════════════════════════════╩══╬═
#                                                               ║
#           c_2: ═══════════════════════════════════════════════╩═

# %%
tqc_ghz_vigo.draw(output='mpl')

# %%
tqc_ghz_vigo_qobj_device = compiler.assemble(tqc_ghz_vigo)
tqc_ghz_vigo_job = ibmq_vigo.run(tqc_ghz_vigo_qobj_device)
job_monitor(tqc_ghz_vigo_job)
# Out:
# Job Status: job has successfully run

# %%
tqc_ghz_vigo_job.status()
# Out:
# <JobStatus.DONE: 'job has successfully run'>

# %%
tqc_ghz_vigo_job.result().get_counts()
# Out:
# {'110': 10,
#  '011': 18,
#  '010': 10,
#  '101': 52,
#  '000': 512,
#  '100': 4,
#  '111': 412,
#  '001': 6}

# %%
plot_histogram([aer_job_ghz.result().get_counts(), tqc_ghz_vigo_job.result().get_counts()],
              legend=['simulator', 'device'], title="3-qubits GHZ state comparison")

# %% [markdown]
# #### Optimization:
# Optimizing the transpiling using (optimization_level=3)

# %%
tqc_ghz_vigo_opt = transpile(qc_ghz, ibmq_vigo, optimization_level=3)
tqc_ghz_vigo_opt.draw()
# Out:
#                            ┌───┐     ┌─┐
#       q_1 -> 0 ────────────┤ X ├─────┤M├──────
#                ┌──────────┐└─┬─┘     └╥┘┌─┐
#       q_0 -> 1 ┤ U2(0,pi) ├──■────■───╫─┤M├───
#                └──────────┘     ┌─┴─┐ ║ └╥┘┌─┐
#       q_2 -> 2 ─────────────────┤ X ├─╫──╫─┤M├
#                                 └───┘ ║  ║ └╥┘
# ancilla_0 -> 3 ───────────────────────╫──╫──╫─
#                                       ║  ║  ║
# ancilla_1 -> 4 ───────────────────────╫──╫──╫─
#                                       ║  ║  ║
#           c_0: ═══════════════════════╬══╩══╬═
#                                       ║     ║
#           c_1: ═══════════════════════╩═════╬═
#                                             ║
#           c_2: ═════════════════════════════╩═

# %% [markdown]
# ## Random Circuits

# %%
from qiskit.circuit.random import random_circuit
import numpy as np

random_circuits = {input_depth: [random_circuit(5, int(input_depth), measure=True, seed=seed)
                                for seed in range(10)]
                  for input_depth in np.linspace(1, 100, num=10)}

# %%
type(random_circuits)
# Out:
# dict

# %%
random_circuits.keys()
# Out:
# dict_keys([1.0, 12.0, 23.0, 34.0, 45.0, 56.0, 67.0, 78.0, 89.0, 100.0])

# %%
random_circuits[12.0][0].draw()
# Out:
#      ┌───────────┐        ┌───┐                          ┌───┐     »
# q_0: ┤ RX(5.735) ├──────■─┤ H ├────────────────────X─────┤ Z ├─────»
#      └───┬───┬───┘      │ └───┘┌───┐               │     └───┘     »
# q_1: ────┤ H ├──────────X──────┤ X ├───────────────X───────■───────»
#          └───┘    ┌───┐ │ ┌───┐└─┬─┘┌────────────┐ │     ┌─┴─┐     »
# q_2: ──────■──────┤ H ├─┼─┤ T ├──┼──┤ RZ(6.1628) ├─┼─────┤ Y ├─────»
#          ┌─┴─┐    └─┬─┘ │ ├───┤  │  └─────┬──────┘ │     └───┘     »
# q_3: ────┤ X ├──────■───┼─┤ X ├──┼────────■────────┼───────■───────»
#          └─┬─┘          │ └───┘  │                 │ ┌─────┴──────┐»
# q_4: ──────■────────────X────────■─────────────────■─┤ RZ(1.9493) ├»
#                                                      └────────────┘»
# c_0: ══════════════════════════════════════════════════════════════»
#                                                                    »
# c_1: ══════════════════════════════════════════════════════════════»
#                                                                    »
# c_2: ══════════════════════════════════════════════════════════════»
#                                                                    »
# c_3: ══════════════════════════════════════════════════════════════»
#                                                                    »
# c_4: ══════════════════════════════════════════════════════════════»
#                                                                    »
# «            ┌───────────┐                                      »
# «q_0: ───────┤ RZ(3.591) ├──────────────X────────────────■───■──»
# «            └─────┬─────┘              │                │ ┌─┴─┐»
# «q_1: ─────────────■────────────────────┼─────────■───X──┼─┤ X ├»
# «                ┌───┐                  │       ┌─┴─┐ │  │ └─┬─┘»
# «q_2: ───────────┤ S ├──────────────────┼───────┤ X ├─X──┼───┼──»
# «                └───┘                  │       └───┘ │  │   │  »
# «q_3: ─────────────■────────────────────X─────────────┼──■───┼──»
# «     ┌────────────┴─────────────┐┌────────────┐      │      │  »
# «q_4: ┤ U3(2.1232,2.4606,5.5938) ├┤ U1(5.2317) ├──────■──────■──»
# «     └──────────────────────────┘└────────────┘                »
# «c_0: ══════════════════════════════════════════════════════════»
# «                                                               »
# «c_1: ══════════════════════════════════════════════════════════»
# «                                                               »
# «c_2: ══════════════════════════════════════════════════════════»
# «                                                               »
# «c_3: ══════════════════════════════════════════════════════════»
# «                                                               »
# «c_4: ══════════════════════════════════════════════════════════»
# «                                                               »
# «     ┌───────────────────────────┐                         ┌───┐┌─┐         »
# «q_0: ┤ U3(2.2941,0.66285,3.9528) ├───────────X─────────────┤ X ├┤M├─────────»
# «     └─────────────┬─────────────┘           │      ┌─────┐└─┬─┘└╥┘┌─┐      »
# «q_1: ──────────────■─────────────────────────X──────┤ TDG ├──┼───╫─┤M├──────»
# «                                  ┌───┐      │      └┬───┬┘  │   ║ └╥┘┌─┐   »
# «q_2: ────────■────────────────────┤ X ├──────■───────┤ H ├───┼───╫──╫─┤M├───»
# «             │1.8761.8768         └─┬─┘             ┌┴───┴┐  │   ║  ║ └╥┘┌─┐»
# «q_3: ────────■──────────────────────■───■───────────┤ TDG ├──┼───╫──╫──╫─┤M├»
# «                                    │   │zz(5.9624) └─────┘  │   ║  ║  ║ └╥┘»
# «q_4: ───────────────────────────────■───■────────────────────■───╫──╫──╫──╫─»
# «                                                                 ║  ║  ║  ║ »
# «c_0: ════════════════════════════════════════════════════════════╩══╬══╬══╬═»
# «                                                                    ║  ║  ║ »
# «c_1: ═══════════════════════════════════════════════════════════════╩══╬══╬═»
# «                                                                       ║  ║ »
# «c_2: ══════════════════════════════════════════════════════════════════╩══╬═»
# «                                                                          ║ »
# «c_3: ═════════════════════════════════════════════════════════════════════╩═»
# «                                                                            »
# «c_4: ═══════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «
# «q_0: ───
# «
# «q_1: ───
# «
# «q_2: ───
# «
# «q_3: ───
# «     ┌─┐
# «q_4: ┤M├
# «     └╥┘
# «c_0: ═╬═
# «      ║
# «c_1: ═╬═
# «      ║
# «c_2: ═╬═
# «      ║
# «c_3: ═╬═
# «      ║
# «c_4: ═╩═
# «

# %%
transpile(random_circuits[12.0][0], ibmq_vigo, optimization_level=3).depth()
# Out:
# 221

# %%
random_circuits[12.0][0].depth()
# Out:
# 13

# %% [markdown]
# We see that taking a depth 13 random quantum circuit and optimizing it to fit the ibmq_vigo device result in an equivalent circuit with depth of 209 !!!

# %% [markdown]
# ### Changing basis of universal gates using transpile

# %% [markdown]
# Toffoli gate:

# %%
ccx_circ = QuantumCircuit(3)
ccx_circ.ccx(0, 1, 2)
ccx_circ.draw(output='mpl')

# %%
transpile(ccx_circ, basis_gates=['h', 't', 'tdg', 'cx']).draw(output='mpl')

# %%
transpile(ccx_circ, basis_gates=['u3', 'cx']).draw(output='mpl')

# %% [markdown]
# Bernstein–Vazirani circuit:

# %%
bv_circ = QuantumCircuit(5, 4)
bv_circ.x(4)
bv_circ.h(range(5))
bv_circ.cx(range(4), 4)
bv_circ.h(range(4))
bv_circ.barrier()
bv_circ.measure(range(4), range(4))
bv_circ.draw(output='mpl')

# %%
transpile(bv_circ, basis_gates=['u3', 'cx']).draw(output='mpl')

# %%
transpile(bv_circ, basis_gates=['rxx', 'ry', 'rx']).draw(output='mpl')

# %% [markdown]
# ### Layout_method

# %%
qc_ghz4 = QuantumCircuit(4, 4)
qc_ghz4.h(0)
qc_ghz4.cx(0, range(1, 4))
qc_ghz4.barrier()
qc_ghz4.measure(range(4), range(4))
qc_ghz4.draw(output='mpl')

# %%
ibmq_ourense = provider.get_backend('ibmq_ourense')
visualization.plot_gate_map(ibmq_ourense)

# %%
transpile(qc_ghz4, ibmq_ourense, layout_method='trivial').draw(output='mpl', scale=0.5)

# %%
transpile(qc_ghz4, ibmq_ourense, layout_method='dense').draw(output='mpl', scale=0.5)

# %%
transpile(qc_ghz4, ibmq_ourense, layout_method='noise_adaptive').draw(output='mpl', scale=0.5)

# %%
transpile(qc_ghz4, ibmq_ourense, initial_layout=[2, 3, 4, 1]).draw(output='mpl', scale=0.5)

# %% [markdown]
# ### Routing
# The objective in Routing is to use SWAP gates in order to construct an equivalent circuit that its two qubits gates are supported in the specific defves we are working on.

# %%
transpile(qc_ghz4, ibmq_vigo, routing_method='basic').draw(output='mpl', scale=0.5)

# %%
transpile(qc_ghz4, ibmq_vigo, routing_method='lookahead').draw(output='mpl', scale=0.5)

# %%
transpile(qc_ghz4, ibmq_vigo, routing_method='stochastic', optimization_level=3).draw(output='mpl', scale=0.5)

# %%
transpile(qc_ghz4, ibmq_vigo, routing_method='stochastic').draw(output='mpl', scale=0.5)

# %% [markdown]
# # Optimization
# ### CXcancellation

# %%
qc = QuantumCircuit(2)
qc.cx(0, 1)
qc.cx(0, 1)
qc.barrier()
qc.cx(1, 0)
qc.cx(0, 1)

print(qc.draw())
transpile(qc).draw()
# Out:
#                 ░ ┌───┐
# q_0: ──■────■───░─┤ X ├──■──
#      ┌─┴─┐┌─┴─┐ ░ └─┬─┘┌─┴─┐
# q_1: ┤ X ├┤ X ├─░───■──┤ X ├
#      └───┘└───┘ ░      └───┘
#       ░ ┌───┐
# q_0: ─░─┤ X ├──■──
#       ░ └─┬─┘┌─┴─┐
# q_1: ─░───■──┤ X ├
#       ░      └───┘

# %% [markdown]
# ## Optimize1qGates

# %%
qc = QuantumCircuit(1)
for i in range(10):
    qc.x(0)
    qc.rx(i, 0)

print(qc.draw())
transpile(qc, basis_gates=['u1', 'u2', 'u3']).draw()
# Out:
#      ┌───┐┌───────┐┌───┐┌───────┐┌───┐┌───────┐┌───┐┌───────┐┌───┐┌───────┐»
# q_0: ┤ X ├┤ RX(0) ├┤ X ├┤ RX(1) ├┤ X ├┤ RX(2) ├┤ X ├┤ RX(3) ├┤ X ├┤ RX(4) ├»
#      └───┘└───────┘└───┘└───────┘└───┘└───────┘└───┘└───────┘└───┘└───────┘»
# «     ┌───┐┌───────┐┌───┐┌───────┐┌───┐┌───────┐┌───┐┌───────┐┌───┐┌───────┐
# «q_0: ┤ X ├┤ RX(5) ├┤ X ├┤ RX(6) ├┤ X ├┤ RX(7) ├┤ X ├┤ RX(8) ├┤ X ├┤ RX(9) ├
# «     └───┘└───────┘└───┘└───────┘└───┘└───────┘└───┘└───────┘└───┘└───────┘
#      ┌────────────────────────┐
# q_0: ┤ U3(1.0177,-pi/2,5pi/2) ├
#      └────────────────────────┘

# %% [markdown]
# ## ComutativeCancellation

# %%
qc = QuantumCircuit(3)
qc.z(0)
qc.x(1)
qc.cx(0, 1)
qc.z(0)
qc.x(1)
qc.barrier()
qc.cx(0, 1)
qc.cx(2, 1)
qc.cx(0, 1)

print(qc.draw())
transpile(qc, optimization_level=2).draw()
# Out:
#      ┌───┐     ┌───┐ ░
# q_0: ┤ Z ├──■──┤ Z ├─░───■─────────■──
#      ├───┤┌─┴─┐├───┤ ░ ┌─┴─┐┌───┐┌─┴─┐
# q_1: ┤ X ├┤ X ├┤ X ├─░─┤ X ├┤ X ├┤ X ├
#      └───┘└───┘└───┘ ░ └───┘└─┬─┘└───┘
# q_2: ────────────────░────────■───────
#                      ░
#            ░
# q_0: ──■───░──────
#      ┌─┴─┐ ░ ┌───┐
# q_1: ┤ X ├─░─┤ X ├
#      └───┘ ░ └─┬─┘
# q_2: ──────░───■──
#            ░

# %% [markdown]
# ## Collect2qBlocks and ConsolidateBlocks

# %%
from qiskit.quantum_info import random_unitary
import logging

logging.basicConfig()
logging.getLogger('qiskit.transpiler').setLevel(logging.INFO)
qc = QuantumCircuit(2)

for _ in range(6):
    u1q = random_unitary(2)
    u2q = random_unitary(2 ** 2)
    
    qc.append(u1q, [0])
    qc.append(u1q, [1])
    qc.append(u2q, [0, 1])
    
print(qc.draw())
transpile(qc, optimization_level=3, basis_gates=['u1', 'u2', 'u3', 'cx']).draw()
# Out:
# INFO:qiskit.transpiler.runningpassmanager:Pass: Unroller - 26.46995 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 0.06390 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.04768 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: RemoveResetInZeroState - 0.14997 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Collect2qBlocks - 2.40207 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: ConsolidateBlocks - 33.37908 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Unroller - 8.48222 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 1.45173 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CommutationAnalysis - 29.91199 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CommutativeCancellation - 0.07915 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: OptimizeSwapBeforeMeasure - 0.02384 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: RemoveDiagonalGatesBeforeMeasure - 0.04196 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 0.06080 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.01836 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: RemoveResetInZeroState - 0.03004 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Collect2qBlocks - 2.09999 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: ConsolidateBlocks - 6.52719 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Unroller - 0.04196 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 1.49202 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CommutationAnalysis - 4.16994 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CommutativeCancellation - 0.18978 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: OptimizeSwapBeforeMeasure - 0.04601 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: RemoveDiagonalGatesBeforeMeasure - 0.04601 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 0.10300 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.05198 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: RemoveResetInZeroState - 0.04101 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Collect2qBlocks - 0.51594 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: ConsolidateBlocks - 8.22020 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Unroller - 0.07200 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 1.05810 (ms)
#      ┌─────────┐┌──────────┐┌─────────┐┌──────────┐┌─────────┐┌──────────┐»
# q_0: ┤ unitary ├┤0         ├┤ unitary ├┤0         ├┤ unitary ├┤0         ├»
#      ├─────────┤│  unitary │├─────────┤│  unitary │├─────────┤│  unitary │»
# q_1: ┤ unitary ├┤1         ├┤ unitary ├┤1         ├┤ unitary ├┤1         ├»
#      └─────────┘└──────────┘└─────────┘└──────────┘└─────────┘└──────────┘»
# «     ┌─────────┐┌──────────┐┌─────────┐┌──────────┐┌─────────┐┌──────────┐
# «q_0: ┤ unitary ├┤0         ├┤ unitary ├┤0         ├┤ unitary ├┤0         ├
# «     ├─────────┤│  unitary │├─────────┤│  unitary │├─────────┤│  unitary │
# «q_1: ┤ unitary ├┤1         ├┤ unitary ├┤1         ├┤ unitary ├┤1         ├
# «     └─────────┘└──────────┘└─────────┘└──────────┘└─────────┘└──────────┘
# INFO:qiskit.transpiler.runningpassmanager:Pass: CommutationAnalysis - 4.92191 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CommutativeCancellation - 0.15998 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: OptimizeSwapBeforeMeasure - 0.25916 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: RemoveDiagonalGatesBeforeMeasure - 0.03719 (ms)
#      ┌───────────────────────────┐       ┌───────────────────┐      »
# q_0: ┤ U3(1.3685,2.2956,-1.4311) ├───■───┤ U3(0.96082,-pi,0) ├───■──»
#      ├───────────────────────────┴┐┌─┴─┐┌┴───────────────────┴┐┌─┴─┐»
# q_1: ┤ U3(0.40154,1.3364,-3.1567) ├┤ X ├┤ U3(0.40012,pi/2,pi) ├┤ X ├»
#      └────────────────────────────┘└───┘└─────────────────────┘└───┘»
# «     ┌───────────────────────┐     ┌────────────────────────────┐
# «q_0: ┤ U3(0.15691,-pi/2,-pi) ├──■──┤ U3(1.9893,-0.37221,1.1635) ├
# «     └─┬────────────────────┬┘┌─┴─┐├────────────────────────────┤
# «q_1: ──┤ U3(pi/2,-pi/2,-pi) ├─┤ X ├┤ U3(2.5895,-2.0437,-2.5097) ├
# «       └────────────────────┘ └───┘└────────────────────────────┘

# %% [markdown]
# ## Circuit with parametrized gate

# %%
theta = circuit.Parameter('theta')

qc = QuantumCircuit(2, 2)
qc.h(0)
qc.rxx(theta, 0, 1)
qc.measure([0, 1], [0, 1])
qc.draw()
# Out:
#      ┌───┐┌─────────────┐┌─┐
# q_0: ┤ H ├┤0            ├┤M├───
#      └───┘│  RXX(theta) │└╥┘┌─┐
# q_1: ─────┤1            ├─╫─┤M├
#           └─────────────┘ ║ └╥┘
# c_0: ═════════════════════╩══╬═
#                              ║
# c_1: ════════════════════════╩═

# %%
transpile(qc, ibmq_vigo).draw()
# Out:
# INFO:qiskit.transpiler.runningpassmanager:Pass: SetLayout - 0.00811 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: TrivialLayout - 0.09012 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Layout2qDistance - 0.60320 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FullAncillaAllocation - 0.09918 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: EnlargeWithAncilla - 0.13185 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: ApplyLayout - 0.79799 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Unroll3qOrMore - 0.03409 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CheckMap - 0.07010 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Unroller - 1.43695 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: RemoveResetInZeroState - 0.04196 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 0.06509 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.03409 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 0.65613 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CXCancellation - 0.13065 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 0.07820 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.02384 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 0.34571 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CXCancellation - 0.14687 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 0.05698 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.02933 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 0.44680 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CXCancellation - 0.11802 (ms)
#                                                   ┌──────────┐┌─┐
#       q_0 -> 0 ──────────────■─────────────────■──┤ U2(0,pi) ├┤M├───
#                ┌──────────┐┌─┴─┐┌───────────┐┌─┴─┐├──────────┤└╥┘┌─┐
#       q_1 -> 1 ┤ U2(0,pi) ├┤ X ├┤ U1(theta) ├┤ X ├┤ U2(0,pi) ├─╫─┤M├
#                └──────────┘└───┘└───────────┘└───┘└──────────┘ ║ └╥┘
# ancilla_0 -> 2 ────────────────────────────────────────────────╫──╫─
#                                                                ║  ║
# ancilla_1 -> 3 ────────────────────────────────────────────────╫──╫─
#                                                                ║  ║
# ancilla_2 -> 4 ────────────────────────────────────────────────╫──╫─
#                                                                ║  ║
#           c_0: ════════════════════════════════════════════════╩══╬═
#                                                                   ║
#           c_1: ═══════════════════════════════════════════════════╩═

# %% [markdown]
# ## Transpile for Simulator

# %%
', '.join(Aer.get_backend('qasm_simulator').configuration().basis_gates)
# Out:
# 'u1, u2, u3, cx, cz, id, x, y, z, h, s, sdg, t, tdg, swap, ccx, unitary, diagonal, initialize, cu1, cu2, cu3, cswap, mcx, mcy, mcz, mcu1, mcu2, mcu3, mcswap, multiplexer, kraus, roerror'

# %%
transpile(qc_ghz, Aer.get_backend('qasm_simulator')).draw(output='mpl', scale=0.5)
# Out:
# INFO:qiskit.transpiler.runningpassmanager:Pass: Unroller - 0.02289 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: RemoveResetInZeroState - 0.03314 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 0.05913 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.03624 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 0.09799 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CXCancellation - 0.11992 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 0.05984 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.02694 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 0.09513 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CXCancellation - 0.13065 (ms)

# %%
from IPython.display import display
from qiskit.converters import dag_to_circuit
from qiskit.transpiler import TransformationPass


def callback_func(pass_, dag, time, property_set, count):
    
    if isinstance(pass_, TransformationPass):
        circuit = dag_to_circuit(dag)
        
        print(pass_.name())
        display(circuit.draw(output='mpl'))

# %%
transpile(qc_ghz4, ibmq_vigo, optimization_level=1, callback=callback_func)
# Out:
# INFO:qiskit.transpiler.runningpassmanager:Pass: SetLayout - 0.00811 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: TrivialLayout - 0.11396 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Layout2qDistance - 0.69189 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: DenseLayout - 8.29101 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FullAncillaAllocation - 0.05913 (ms)
# EnlargeWithAncilla
# INFO:qiskit.transpiler.runningpassmanager:Pass: EnlargeWithAncilla - 0.09513 (ms)
# ApplyLayout
# INFO:qiskit.transpiler.runningpassmanager:Pass: ApplyLayout - 0.67687 (ms)
# Unroll3qOrMore
# INFO:qiskit.transpiler.runningpassmanager:Pass: Unroll3qOrMore - 0.02885 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CheckMap - 0.05388 (ms)
# BarrierBeforeFinalMeasurements
# INFO:qiskit.transpiler.runningpassmanager:Pass: BarrierBeforeFinalMeasurements - 3.33428 (ms)
# StochasticSwap
# INFO:qiskit.transpiler.runningpassmanager:Pass: StochasticSwap - 13.65614 (ms)
# Unroller
# INFO:qiskit.transpiler.runningpassmanager:Pass: Unroller - 0.91720 (ms)
# RemoveResetInZeroState
# INFO:qiskit.transpiler.runningpassmanager:Pass: RemoveResetInZeroState - 0.03290 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 0.06104 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.03481 (ms)
# Optimize1qGates
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 0.21625 (ms)
# CXCancellation
# INFO:qiskit.transpiler.runningpassmanager:Pass: CXCancellation - 0.20099 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 0.04601 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.02193 (ms)
# Optimize1qGates
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 0.31614 (ms)
# CXCancellation
# INFO:qiskit.transpiler.runningpassmanager:Pass: CXCancellation - 0.16904 (ms)
